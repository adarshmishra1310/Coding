# %%
import numpy as np

# %%
# Declaration of numpy array
a = np.array([32,61,72])

# %%
print(a,a[1])
# Out:
# [32 61 72] 61

# %%
np.dot?

# %%
b = np.array([82,23,12])

# %%
a*b #multiplies two arrays
# Out:
# array([2624, 1403,  864])

# %%
p=(a*b).sum() # tell sum of array
print(p)
print(type(p))
# Out:
# 4891
# <class 'numpy.int64'>

# %%
a.sum()
# Out:
# np.int64(165)
